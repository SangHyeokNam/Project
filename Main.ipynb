# %%
import sys, os
sys.path.append(os.pardir)
from scankorean.scankorean import ScanKorean

# %%
input_image = 'E:/data/한글 data/사진 test/ㄴ2.png'
model_name = "./Korean-4 model/Korean-4 model.hdf5"

# %%
ScanKorean(input_image, model_name)
# Out:
# 판별할 글자 이미지
# ...
# 판별 결과: ㄴ
# ...
